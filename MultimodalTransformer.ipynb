# %%
import pandas as pd
from google.colab import drive

drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --dataset IEMOCAP
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# ### Note: You are running in unaligned mode.
# /content/gdrive/MyDrive/Multimodal/modules/position_embedding.py:21: UserWarning: The number of elements in the out tensor of shape [18] is 18 which does not match the computed number of elements 396. Note that this may occur as a result of rounding error. The out tensor will be resized to a tensor of shape (396,). (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/RangeFactories.cu:267.)
#   torch.arange(padding_idx + 1, max_pos, out=getattr(make_positions, buf_name))
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --vonly --dataset iemocap
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# ### Note: You are running in unaligned mode.
# Epoch  1 | Batch  30/ 84 | Time/Batch(ms) 246.93 | Train Loss 0.5807
# Epoch  1 | Batch  60/ 84 | Time/Batch(ms) 236.06 | Train Loss 0.5537
# --------------------------------------------------
# Epoch  1 | Time 24.7469 sec | Valid Loss 0.5425 | Test Loss 0.5419
# --------------------------------------------------
# Saved model at pre_trained_models/mult.pt!
# Epoch  2 | Batch  30/ 84 | Time/Batch(ms) 244.49 | Train Loss 0.5523
# Epoch  2 | Batch  60/ 84 | Time/Batch(ms) 235.83 | Train Loss 0.5392
# --------------------------------------------------
# Epoch  2 | Time 24.6198 sec | Valid Loss 0.5274 | Test Loss 0.5425
# --------------------------------------------------
# Saved model at pre_trained_models/mult.pt!
# Epoch  3 | Batch  30/ 84 | Time/Batch(ms) 244.40 | Train Loss 0.5430
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py  34
# Out:
# usage: main.py [-h] [-f F] [--model MODEL] [--vonly] [--aonly] [--lonly]
#                [--aligned] [--dataset DATASET] [--data_path DATA_PATH]
#                [--attn_dropout ATTN_DROPOUT] [--attn_dropout_a ATTN_DROPOUT_A]
#                [--attn_dropout_v ATTN_DROPOUT_V] [--relu_dropout RELU_DROPOUT]
#                [--embed_dropout EMBED_DROPOUT] [--res_dropout RES_DROPOUT]
#                [--out_dropout OUT_DROPOUT] [--nlevels NLEVELS]
#                [--num_heads NUM_HEADS] [--attn_mask] [--batch_size N]
#                [--clip CLIP] [--lr LR] [--optim OPTIM]
#                [--num_epochs NUM_EPOCHS] [--when WHEN]
#                [--batch_chunk BATCH_CHUNK] [--log_interval LOG_INTERVAL]
#                [--seed SEED] [--no_cuda] [--name NAME]
# main.py: error: unrecognized arguments: 34

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --lonly --dataset iemocap
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# ### Note: You are running in unaligned mode.
# /content/gdrive/MyDrive/Multimodal/modules/position_embedding.py:21: UserWarning: The number of elements in the out tensor of shape [18] is 18 which does not match the computed number of elements 396. Note that this may occur as a result of rounding error. The out tensor will be resized to a tensor of shape (396,). (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/RangeFactories.cu:267.)
#   torch.arange(padding_idx + 1, max_pos, out=getattr(make_positions, buf_name))
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --aonly --dataset iemocap
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# ### Note: You are running in unaligned mode.
# /content/gdrive/MyDrive/Multimodal/modules/position_embedding.py:21: UserWarning: The number of elements in the out tensor of shape [396] is 396 which does not match the computed number of elements 498. Note that this may occur as a result of rounding error. The out tensor will be resized to a tensor of shape (498,). (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/RangeFactories.cu:267.)
#   torch.arange(padding_idx + 1, max_pos, out=getattr(make_positions, buf_name))
# Epoch  1 | Batch  30/ 84 | Time/Batch(ms) 207.41 | Train Loss 0.5696
# Epoch  1 | Batch  60/ 84 | Time/Batch(ms) 198.37 | Train Loss 0.5557
# --------------------------------------------------
# Epoch  1 | Time 20.8812 sec | Valid Loss 0.5303 | Test Loss 0.5369
# --------------------------------------------------
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --aligned --dataset iemocap
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# Epoch  1 | Batch  30/ 84 | Time/Batch(ms) 141.20 | Train Loss 0.5945
# Epoch  1 | Batch  60/ 84 | Time/Batch(ms) 127.55 | Train Loss 0.5460
# --------------------------------------------------
# Epoch  1 | Time 13.1546 sec | Valid Loss 0.4858 | Test Loss 0.4759
# --------------------------------------------------
# Saved model at pre_trained_models/mult.pt!
# Epoch  2 | Batch  30/ 84 | Time/Batch(ms) 141.99 | Train Loss 0.4827
# Epoch  2 | Batch  60/ 84 | Time/Batch(ms) 135.41 | Train Loss 0.4814
# --------------------------------------------------
# Epoch  2 | Time 13.6185 sec | Valid Loss 0.4766 | Test Loss 0.4696
# --------------------------------------------------
# Saved model at pre_trained_models/mult.pt!
# Epoch  3 | Batch  30/ 84 | Time/Batch(ms) 142.04 | Train Loss 0.4342
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --lonly --aligned --dataset iemocap
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# Epoch  1 | Batch  30/ 84 | Time/Batch(ms) 47.79 | Train Loss 0.5783
# Epoch  1 | Batch  60/ 84 | Time/Batch(ms) 44.49 | Train Loss 0.5316
# --------------------------------------------------
# Epoch  1 | Time 4.6875 sec | Valid Loss 0.5015 | Test Loss 0.4954
# --------------------------------------------------
# Saved model at pre_trained_models/mult.pt!
# Epoch  2 | Batch  30/ 84 | Time/Batch(ms) 48.72 | Train Loss 0.4615
# Epoch  2 | Batch  60/ 84 | Time/Batch(ms) 44.92 | Train Loss 0.4528
# --------------------------------------------------
# Epoch  2 | Time 4.7150 sec | Valid Loss 0.4730 | Test Loss 0.4458
# --------------------------------------------------
# Saved model at pre_trained_models/mult.pt!
# Epoch  3 | Batch  30/ 84 | Time/Batch(ms) 46.67 | Train Loss 0.4135
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --aonly --aligned --dataset iemocap
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# /content/gdrive/MyDrive/Multimodal/modules/position_embedding.py:21: UserWarning: The number of elements in the out tensor of shape [16] is 16 which does not match the computed number of elements 18. Note that this may occur as a result of rounding error. The out tensor will be resized to a tensor of shape (18,). (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/RangeFactories.cu:267.)
#   torch.arange(padding_idx + 1, max_pos, out=getattr(make_positions, buf_name))
# Epoch  1 | Batch  30/ 84 | Time/Batch(ms) 48.62 | Train Loss 0.5690
# Epoch  1 | Batch  60/ 84 | Time/Batch(ms) 46.28 | Train Loss 0.5464
# --------------------------------------------------
# Epoch  1 | Time 4.7471 sec | Valid Loss 0.5111 | Test Loss 0.5061
# --------------------------------------------------
# Saved model at pre_trained_models/mult.pt!
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --vonly --aligned --dataset iemocap
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# Epoch  1 | Batch  30/ 84 | Time/Batch(ms) 47.95 | Train Loss 0.5757
# Epoch  1 | Batch  60/ 84 | Time/Batch(ms) 46.93 | Train Loss 0.5388
# --------------------------------------------------
# Epoch  1 | Time 4.7929 sec | Valid Loss 0.5343 | Test Loss 0.5232
# --------------------------------------------------
# Saved model at pre_trained_models/mult.pt!
# Epoch  2 | Batch  30/ 84 | Time/Batch(ms) 47.48 | Train Loss 0.5168
# Epoch  2 | Batch  60/ 84 | Time/Batch(ms) 44.44 | Train Loss 0.5157
# --------------------------------------------------
# Epoch  2 | Time 4.6166 sec | Valid Loss 0.5214 | Test Loss 0.5083
# --------------------------------------------------
# Saved model at pre_trained_models/mult.pt!
# Epoch  3 | Batch  30/ 84 | Time/Batch(ms) 46.28 | Train Loss 0.4805
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --dataset IEMOCAP --num_epochs 10
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# ### Note: You are running in unaligned mode.
# /content/gdrive/MyDrive/Multimodal/modules/position_embedding.py:21: UserWarning: The number of elements in the out tensor of shape [18] is 18 which does not match the computed number of elements 396. Note that this may occur as a result of rounding error. The out tensor will be resized to a tensor of shape (396,). (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/RangeFactories.cu:267.)
#   torch.arange(padding_idx + 1, max_pos, out=getattr(make_positions, buf_name))
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --dataset IEMOCAP --num_epochs 5
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# ### Note: You are running in unaligned mode.
# /content/gdrive/MyDrive/Multimodal/modules/position_embedding.py:21: UserWarning: The number of elements in the out tensor of shape [18] is 18 which does not match the computed number of elements 396. Note that this may occur as a result of rounding error. The out tensor will be resized to a tensor of shape (396,). (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/RangeFactories.cu:267.)
#   torch.arange(padding_idx + 1, max_pos, out=getattr(make_positions, buf_name))
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --dataset IEMOCAP --num_epochs 5 --seed 100
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# ### Note: You are running in unaligned mode.
# /content/gdrive/MyDrive/Multimodal/modules/position_embedding.py:21: UserWarning: The number of elements in the out tensor of shape [18] is 18 which does not match the computed number of elements 396. Note that this may occur as a result of rounding error. The out tensor will be resized to a tensor of shape (396,). (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/RangeFactories.cu:267.)
#   torch.arange(padding_idx + 1, max_pos, out=getattr(make_positions, buf_name))
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --dataset IEMOCAP --num_epochs 5 --nlevels 2
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# ### Note: You are running in unaligned mode.
# /content/gdrive/MyDrive/Multimodal/modules/position_embedding.py:21: UserWarning: The number of elements in the out tensor of shape [18] is 18 which does not match the computed number of elements 396. Note that this may occur as a result of rounding error. The out tensor will be resized to a tensor of shape (396,). (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/RangeFactories.cu:267.)
#   torch.arange(padding_idx + 1, max_pos, out=getattr(make_positions, buf_name))
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --dataset IEMOCAP --num_epochs 5 --attn_dropout 0.2 --out_dropout 0.2
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# ### Note: You are running in unaligned mode.
# /content/gdrive/MyDrive/Multimodal/modules/position_embedding.py:21: UserWarning: The number of elements in the out tensor of shape [18] is 18 which does not match the computed number of elements 396. Note that this may occur as a result of rounding error. The out tensor will be resized to a tensor of shape (396,). (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/RangeFactories.cu:267.)
#   torch.arange(padding_idx + 1, max_pos, out=getattr(make_positions, buf_name))
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --dataset IEMOCAP --num_epochs 5 --batch_size 20
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# ### Note: You are running in unaligned mode.
# /content/gdrive/MyDrive/Multimodal/modules/position_embedding.py:21: UserWarning: The number of elements in the out tensor of shape [18] is 18 which does not match the computed number of elements 396. Note that this may occur as a result of rounding error. The out tensor will be resized to a tensor of shape (396,). (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/RangeFactories.cu:267.)
#   torch.arange(padding_idx + 1, max_pos, out=getattr(make_positions, buf_name))
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --dataset IEMOCAP --batch_size 16
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# ### Note: You are running in unaligned mode.
# /content/gdrive/MyDrive/Multimodal/modules/position_embedding.py:21: UserWarning: The number of elements in the out tensor of shape [18] is 18 which does not match the computed number of elements 396. Note that this may occur as a result of rounding error. The out tensor will be resized to a tensor of shape (396,). (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/RangeFactories.cu:267.)
#   torch.arange(padding_idx + 1, max_pos, out=getattr(make_positions, buf_name))
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --dataset IEMOCAP --num_epochs 5 --lr 1e-3
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# ### Note: You are running in unaligned mode.
# /content/gdrive/MyDrive/Multimodal/modules/position_embedding.py:21: UserWarning: The number of elements in the out tensor of shape [18] is 18 which does not match the computed number of elements 396. Note that this may occur as a result of rounding error. The out tensor will be resized to a tensor of shape (396,). (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/RangeFactories.cu:267.)
#   torch.arange(padding_idx + 1, max_pos, out=getattr(make_positions, buf_name))
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --dataset IEMOCAP --num_epochs 5 --optim SGD
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# ### Note: You are running in unaligned mode.
# /content/gdrive/MyDrive/Multimodal/modules/position_embedding.py:21: UserWarning: The number of elements in the out tensor of shape [18] is 18 which does not match the computed number of elements 396. Note that this may occur as a result of rounding error. The out tensor will be resized to a tensor of shape (396,). (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/RangeFactories.cu:267.)
#   torch.arange(padding_idx + 1, max_pos, out=getattr(make_positions, buf_name))
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --dataset IEMOCAP --num_epochs 5 
# Hidden unit 30
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# ### Note: You are running in unaligned mode.
# /content/gdrive/MyDrive/Multimodal/modules/position_embedding.py:21: UserWarning: The number of elements in the out tensor of shape [18] is 18 which does not match the computed number of elements 396. Note that this may occur as a result of rounding error. The out tensor will be resized to a tensor of shape (396,). (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/RangeFactories.cu:267.)
#   torch.arange(padding_idx + 1, max_pos, out=getattr(make_positions, buf_name))
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --dataset IEMOCAP --num_epochs 5 
# Temporal Convolution Kernel Size (L/V/A) -3/3/3
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# ### Note: You are running in unaligned mode.
# /content/gdrive/MyDrive/Multimodal/modules/position_embedding.py:21: UserWarning: The number of elements in the out tensor of shape [18] is 18 which does not match the computed number of elements 398. Note that this may occur as a result of rounding error. The out tensor will be resized to a tensor of shape (398,). (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/RangeFactories.cu:267.)
#   torch.arange(padding_idx + 1, max_pos, out=getattr(make_positions, buf_name))
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --dataset IEMOCAP --num_epochs 5 --num_heads 8
# num_heads
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# ### Note: You are running in unaligned mode.
# /content/gdrive/MyDrive/Multimodal/modules/position_embedding.py:21: UserWarning: The number of elements in the out tensor of shape [18] is 18 which does not match the computed number of elements 396. Note that this may occur as a result of rounding error. The out tensor will be resized to a tensor of shape (396,). (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/RangeFactories.cu:267.)
#   torch.arange(padding_idx + 1, max_pos, out=getattr(make_positions, buf_name))
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --dataset IEMOCAP --num_epochs 5 --lr 3e-3
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# ### Note: You are running in unaligned mode.
# /content/gdrive/MyDrive/Multimodal/modules/position_embedding.py:21: UserWarning: The number of elements in the out tensor of shape [18] is 18 which does not match the computed number of elements 396. Note that this may occur as a result of rounding error. The out tensor will be resized to a tensor of shape (396,). (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/RangeFactories.cu:267.)
#   torch.arange(padding_idx + 1, max_pos, out=getattr(make_positions, buf_name))
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --dataset IEMOCAP --num_epochs 5 --attn_dropout 0.1
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# ### Note: You are running in unaligned mode.
# /content/gdrive/MyDrive/Multimodal/modules/position_embedding.py:21: UserWarning: The number of elements in the out tensor of shape [18] is 18 which does not match the computed number of elements 396. Note that this may occur as a result of rounding error. The out tensor will be resized to a tensor of shape (396,). (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/RangeFactories.cu:267.)
#   torch.arange(padding_idx + 1, max_pos, out=getattr(make_positions, buf_name))
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --dataset IEMOCAP --num_epochs 5 --attn_dropout 0
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# ### Note: You are running in unaligned mode.
# /content/gdrive/MyDrive/Multimodal/modules/position_embedding.py:21: UserWarning: The number of elements in the out tensor of shape [18] is 18 which does not match the computed number of elements 396. Note that this may occur as a result of rounding error. The out tensor will be resized to a tensor of shape (396,). (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/RangeFactories.cu:267.)
#   torch.arange(padding_idx + 1, max_pos, out=getattr(make_positions, buf_name))
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --dataset IEMOCAP --num_epochs 5
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# ### Note: You are running in unaligned mode.
# /content/gdrive/MyDrive/Multimodal/modules/position_embedding.py:21: UserWarning: The number of elements in the out tensor of shape [18] is 18 which does not match the computed number of elements 396. Note that this may occur as a result of rounding error. The out tensor will be resized to a tensor of shape (396,). (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/RangeFactories.cu:267.)
#   torch.arange(padding_idx + 1, max_pos, out=getattr(make_positions, buf_name))
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --dataset IEMOCAP --num_epochs 5
#GRU
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# ### Note: You are running in unaligned mode.
# /content/gdrive/MyDrive/Multimodal/modules/position_embedding.py:21: UserWarning: The number of elements in the out tensor of shape [18] is 18 which does not match the computed number of elements 396. Note that this may occur as a result of rounding error. The out tensor will be resized to a tensor of shape (396,). (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/RangeFactories.cu:267.)
#   torch.arange(padding_idx + 1, max_pos, out=getattr(make_positions, buf_name))
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --aligned --dataset IEMOCAP --num_epochs 5
#GRU
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# Epoch  1 | Batch  30/ 84 | Time/Batch(ms) 99.15 | Train Loss 0.5805
# Epoch  1 | Batch  60/ 84 | Time/Batch(ms) 93.52 | Train Loss 0.5089
# --------------------------------------------------
# Epoch  1 | Time 9.5397 sec | Valid Loss 0.4927 | Test Loss 0.4636
# --------------------------------------------------
# Saved model at pre_trained_models/mult.pt!
# Epoch  2 | Batch  30/ 84 | Time/Batch(ms) 98.61 | Train Loss 0.4479
# Epoch  2 | Batch  60/ 84 | Time/Batch(ms) 96.33 | Train Loss 0.4593
# --------------------------------------------------
# Epoch  2 | Time 9.6265 sec | Valid Loss 0.5242 | Test Loss 0.4841
# --------------------------------------------------
# Epoch  3 | Batch  30/ 84 | Time/Batch(ms) 96.08 | Train Loss 0.4060
# Epoch  3 | Batch  60/ 84 | Time/Batch(ms) 93.46 | Train Loss 0.4001
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --aligned --dataset IEMOCAP --num_epochs 5
#LSTM
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# Epoch  1 | Batch  30/ 84 | Time/Batch(ms) 99.72 | Train Loss 0.5805
# Epoch  1 | Batch  60/ 84 | Time/Batch(ms) 92.06 | Train Loss 0.5083
# --------------------------------------------------
# Epoch  1 | Time 9.5064 sec | Valid Loss 0.4928 | Test Loss 0.4644
# --------------------------------------------------
# Saved model at pre_trained_models/mult.pt!
# Epoch  2 | Batch  30/ 84 | Time/Batch(ms) 93.26 | Train Loss 0.4502
# Epoch  2 | Batch  60/ 84 | Time/Batch(ms) 94.92 | Train Loss 0.4614
# --------------------------------------------------
# Epoch  2 | Time 9.3758 sec | Valid Loss 0.4985 | Test Loss 0.4573
# --------------------------------------------------
# Epoch  3 | Batch  30/ 84 | Time/Batch(ms) 98.58 | Train Loss 0.4063
# Epoch  3 | Batch  60/ 84 | Time/Batch(ms) 93.60 | Train Loss 0.4000
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --lonly --dataset IEMOCAP --num_epochs 5
# Text only
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# ### Note: You are running in unaligned mode.
# /content/gdrive/MyDrive/Multimodal/modules/position_embedding.py:21: UserWarning: The number of elements in the out tensor of shape [18] is 18 which does not match the computed number of elements 396. Note that this may occur as a result of rounding error. The out tensor will be resized to a tensor of shape (396,). (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/RangeFactories.cu:267.)
#   torch.arange(padding_idx + 1, max_pos, out=getattr(make_positions, buf_name))
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --video --dataset iemocap --num_epochs 5
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# ### Note: You are running in unaligned mode.
# /content/gdrive/MyDrive/Multimodal/modules/position_embedding.py:21: UserWarning: The number of elements in the out tensor of shape [18] is 18 which does not match the computed number of elements 396. Note that this may occur as a result of rounding error. The out tensor will be resized to a tensor of shape (396,). (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/RangeFactories.cu:267.)
#   torch.arange(padding_idx + 1, max_pos, out=getattr(make_positions, buf_name))
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --language --dataset iemocap --num_epochs 5
#batch size 16
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# ### Note: You are running in unaligned mode.
# /content/gdrive/MyDrive/Multimodal/modules/position_embedding.py:21: UserWarning: The number of elements in the out tensor of shape [18] is 18 which does not match the computed number of elements 396. Note that this may occur as a result of rounding error. The out tensor will be resized to a tensor of shape (396,). (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/RangeFactories.cu:267.)
#   torch.arange(padding_idx + 1, max_pos, out=getattr(make_positions, buf_name))
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --audio --dataset iemocap --num_epochs 5
# batch size =16
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# ### Note: You are running in unaligned mode.
# /content/gdrive/MyDrive/Multimodal/modules/position_embedding.py:21: UserWarning: The number of elements in the out tensor of shape [18] is 18 which does not match the computed number of elements 396. Note that this may occur as a result of rounding error. The out tensor will be resized to a tensor of shape (396,). (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/RangeFactories.cu:267.)
#   torch.arange(padding_idx + 1, max_pos, out=getattr(make_positions, buf_name))
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --dataset IEMOCAP --num_epochs 5 --attn_dropout 0.05
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# ### Note: You are running in unaligned mode.
# /content/gdrive/MyDrive/Multimodal/modules/position_embedding.py:21: UserWarning: The number of elements in the out tensor of shape [18] is 18 which does not match the computed number of elements 396. Note that this may occur as a result of rounding error. The out tensor will be resized to a tensor of shape (396,). (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/RangeFactories.cu:267.)
#   torch.arange(padding_idx + 1, max_pos, out=getattr(make_positions, buf_name))
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --dataset IEMOCAP --num_epochs 5
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# ### Note: You are running in unaligned mode.
# /content/gdrive/MyDrive/Multimodal/modules/position_embedding.py:21: UserWarning: The number of elements in the out tensor of shape [18] is 18 which does not match the computed number of elements 396. Note that this may occur as a result of rounding error. The out tensor will be resized to a tensor of shape (396,). (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/RangeFactories.cu:267.)
#   torch.arange(padding_idx + 1, max_pos, out=getattr(make_positions, buf_name))
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --dataset mosi
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# ### Note: You are running in unaligned mode.
# /content/gdrive/MyDrive/Multimodal/modules/position_embedding.py:21: UserWarning: The number of elements in the out tensor of shape [48] is 48 which does not match the computed number of elements 373. Note that this may occur as a result of rounding error. The out tensor will be resized to a tensor of shape (373,). (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/RangeFactories.cu:267.)
#   torch.arange(padding_idx + 1, max_pos, out=getattr(make_positions, buf_name))
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --aligned --dataset mosi
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/loss.py:96: UserWarning: Using a target size (torch.Size([32, 4])) that is different to the input size (torch.Size([32, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.l1_loss(input, target, reduction=self.reduction)
# Epoch  1 | Batch  30/ 84 | Time/Batch(ms) 221.34 | Train Loss 0.5779
# Epoch  1 | Batch  60/ 84 | Time/Batch(ms) 202.66 | Train Loss 0.3233
# Traceback (most recent call last):
#   File "/content/gdrive/MyDrive/Multimodal/main.py", line 159, in <module>
#     test_loss = train.initiate(hyp_params, train_loader, valid_loader, test_loader)
#   File "/content/gdrive/MyDrive/Multimodal/src/train.py", line 63, in initiate
# ...

# %%
# !python /content/gdrive/MyDrive/Multimodal/main.py --ef --dataset iemocap
# Out:
# Start loading the data....
#   - Found cached train data
#   - Found cached valid data
#   - Found cached test data
# Finish loading the data....
# ### Note: You are running in unaligned mode.
# /content/gdrive/MyDrive/Multimodal/modules/position_embedding.py:21: UserWarning: The number of elements in the out tensor of shape [18] is 18 which does not match the computed number of elements 398. Note that this may occur as a result of rounding error. The out tensor will be resized to a tensor of shape (398,). (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/RangeFactories.cu:267.)
#   torch.arange(padding_idx + 1, max_pos, out=getattr(make_positions, buf_name))
# ...
